# %%
from astroquery.vizier import Vizier
import pandas as pd
from tqdm import tqdm
import joblib

# %%
df = pd.read_csv('/home/mariia/AstroML/data/asassn/preprocessed_data/sub50_lb/spectra_and_v_train_norm.csv')

# %%
df[df['target'] == 'ROT']['id']
# Out:
# 1         EDR3 68317609532996480
# 5       EDR3 4013710404844589568
# 9       EDR3 4581399871861478144
# 10       EDR3 112391704932879360
# 11       EDR3 689402453566470656
#                   ...
# 8517     EDR3 659215911582235648
# 8518    EDR3 1346916660448878592
# 8519    EDR3 1948787229553042048
# 8520      EDR3 70132658415356672
# 8521      EDR3 66754241438299520
# Name: id, Length: 1209, dtype: object

# %%
# Gaia DR3 varstar catalogs
# cf https://vizier.cds.unistra.fr/viz-bin/VizieR?-source=I/358
cat_base = "I/358/"
g_var_lookup = {"VCR": "vclassre",
                "VRRLyr": "vrrlyr",
                "VCep": "vceph",
                "VPN": "vpltrans",
                "VST": "vst",
                "VLPV": "vlpl",
                "VEB": "veb",
                "VRM": "vrmo",
                "VMSO": "vmsosc",
                "VAGN": "vagn",
                "Vmicro": "vmicro",
                "VCC": "vcc"}
g_var_keys = list(g_var_lookup.keys())

# %%
info = Vizier(catalog="J/ApJS/232/16").query_constraints(ID='J080735.59+165240.7')

# %%
info
# Out:
# Empty TableList

# %%
vizier = Vizier(columns=["*"], row_limit=50)

# %%
result = vizier.query_object('J121603.08+301338.0')
# Out:
# WARNING: UnitsWarning: Unit 'meta' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'code' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'pct' not supported by the VOUnit standard. Did you mean PC, PT, Pct, pC, pT or pc? [astropy.units.format.vounit]

# %%
result[0]
# Out:
# <Table length=7>
#   USNO-A1.0    RA_ICRS    DE_ICRS   GSCflag Mflag   Bmag    Rmag  _tab1_8
#                  deg        deg                     mag     mag      yr
#     str13      float64    float64     str1   str1 float32 float32 float64
# ------------- ---------- ---------- ------- ----- ------- ------- --------
# 1200-06934010 183.993037  30.202484                  20.6    19.1 1955.292
# 1200-06934070 183.998000  30.208431                  21.3    19.3 1955.292
# 1200-06934160 184.006359  30.203850                  20.7    18.9 1955.292
# 1200-06934232 184.012673  30.227306       G          13.7    12.7 1955.292
# 1200-06934471 184.036375  30.243487                  20.3    18.1 1955.292
# 1200-06934497 184.039325  30.236087                  20.3    17.9 1955.292
# 1200-06934206 184.009898  30.260287                  19.8    17.4 1955.292

# %%
gids = ['J073232.72+264715.3', 'J015806.12+383918.8', 'J075224.81+043358.6', 'J091505.26+191737.4', 'J064316.47+173645.7', 'J091331.92+193422.4', 'J235954.28+565846.5', 'J055704.81+254452.3', 'J020406.50+532941.4', 'J050125.21+241836.8', 'J125149.81+013001.3', 'J061822.81+343814.5', 'J082915.17+182307.3', 'J053656.76+520232.4', 'J065544.07+000250.5', 'J040401.81+271545.1']

for gid in tqdm(gids):
    try:
', '1949476004869772800', '948110392756169728', '4473922404086827392', '3453614401357270400', '191979403135335040', '2128919424960482176', '3437941829473147264', '3359214284368618752', '635938803743669504', '1995023961249856896', '3429801011022038912', '360192866734187392', '3403591814907805696', '3947992246959480064', '4275054728104988928', '402007976833735936', '3419512983797945728', '1449983780923890176', '4478532587636804736', '336015087072296448', '4583632808177665408', '1899796393033966720', '3702533805136832128', '4509789018846155392', '3452607424800795392', '274326643600982784', '2076362498581178752', '238380516113396992', '662279185337050752', '4287332497743466624', '4543284201771197312', '227882791407954432', '4371313195844700928', '4488866828693883136', '2101457717606926336', '3352366903905401728', '263516344056616576', '422777240388547840', '4353079822719799680', '1788375144551110016', '3113305111497306368', '5763531414684412160', '152576587183322880', '1965901918316222464', '307883012627596288', '163477484762516992', '212049789607829760', '115567094512098688', '816537230738934528', '3383389044666877696', '4485164601251432960', '2076739424908693888', '171901534833480064', '260355763523125248', '3236116776451428480', '3681156752176316928', '335268553037161600', '2709374187608515328', '2128910152129554432', '3406626673160696576', '2873811241079717120', '4341464233990094464', '4523492786317552256', '1326077754006291968', '3288382134693751808']

# %%
res = {}

for gid in tqdm(ids):
    print(gid)

    try:
        info = Vizier(catalog="I/358/varisum", columns=['*', '_RAJ2000', '_DEJ2000']).query_constraints(Source=gid)[0]
    except:
        # print('Error\n')
        continue
    
    for vtype in g_var_keys:
        if info[vtype] == 1:
            # print(vtype)
            gaia_source = Vizier(catalog=f"I/358/{g_var_lookup[vtype]}", columns=['*']).query_constraints(Source=gid)
            
            if len(gaia_source) > 0:
                gaia_source = gaia_source[0]
                
                try:
                    cls = gaia_source['Class'].data[0]
                    res[gid] = cls
                    print(f"class={cls}")
                except:
                    pass
                    
                # try:
                #     period1 = 1/gaia_source['Freq'].data[0]
                #     res[gid].append(period1)
                #     print(f"period={period1} d")
                # except:
                #     pass
                    
                # try:
                #     period2 = 1/gaia_source['FundFreq1'].data[0]
                #     res[gid].append(period2)
                #     print(f"period={period2} d")
                # except:
                #     pass
    # print()
# Out:
#   0%|                                                                                          | 0/216 [00:00<?, ?it/s]
# 4480057507185436800
# class=LPV
#   0%|▍                                                                                 | 1/216 [00:04<16:40,  4.65s/it]
# 4523444613962933888
# class=LPV
#   1%|▊                                                                                 | 2/216 [00:08<14:49,  4.16s/it]
# 261101855181720064
# class=LPV
#   1%|█▏                                                                                | 3/216 [00:12<14:06,  3.98s/it]
# 2052432654486484480
# class=LPV
#   2%|█▌                                                                                | 4/216 [00:16<14:04,  3.98s/it]
# 4479346020086286464
# class=LPV
#   2%|█▉                                                                                | 5/216 [00:20<13:51,  3.94s/it]
# 275972062756505216
# class=LPV
# ...

# %%
set(res.values())
# Out:
# {'LPV'}

# %%
res
# Out:
# {'4480057507185436800': 'LPV',
#  '4523444613962933888': 'LPV',
#  '261101855181720064': 'LPV',
#  '2052432654486484480': 'LPV',
#  '4479346020086286464': 'LPV',
#  '275972062756505216': 'LPV',
#  '2107132571992429696': 'LPV',
#  '913620117446154112': 'LPV',
#  '396085835409005696': 'LPV',
#  '872296282883209344': 'LPV',
#  '178910268626478848': 'LPV',
#  '1784835546038294656': 'LPV',
#  '199305419047951872': 'LPV',
#  '3448981196797635968': 'LPV',
#  '3238016118364248320': 'LPV',
#  '342977194698972928': 'LPV',
#  '3089461892611624448': 'LPV',
#  '3094574552961246208': 'LPV',
#  '3403858549559988608': 'LPV',
#  '1941294710643302528': 'LPV',
#  '4517961899245287936': 'LPV',
#  '888350355239966848': 'LPV',
#  '4286587990926663680': 'LPV',
#  '389679569565005312': 'LPV',
#  '376816623550472960': 'LPV',
#  '2101851102246674432': 'LPV',
#  '2077102401185363072': 'LPV',
#  '635892040139785344': 'LPV',
#  '4483936412402978944': 'LPV',
#  '258807891671878656': 'LPV',
# ...

# %%
joblib.dump(res, 'rot-classes.pkl')
# Out:
# ['rot-classes.pkl']

# %%
gaia_source
# Out:
# <Table length=1>
#        Source             SolID        ...     RA_ICRS         DE_ICRS
#                                        ...       deg             deg
#        int64              int64        ...     float64         float64
# ------------------- ------------------ ... --------------- ---------------
# 3788835194355703296 375316653866487564 ... 165.50977100442  -4.90815583629

# %%
info
# Out:
# <Table length=1>
#      _RAJ2000          _DEJ2000           Source       ...  VAGN Vmicro  VCC
#        deg               deg                           ...
#      float64           float64            int64        ... uint8 uint8  uint8
# ----------------- ----------------- ------------------ ... ----- ------ -----
#   9.6725738324310  45.2517432209207 388263639106045312 ...     0      0     0

# %%
res = joblib.load('rot-classes.pkl')

# %%
list(res.keys())[0]
# Out:
# '4013710404844589568'

# %%
info = Vizier(catalog="I/358/varisum", columns=['*', '_RAJ2000', '_DEJ2000']).query_constraints(Source='1935790967751641984')[0]

# %%
info
# Out:
# <Table length=1>
#      _RAJ2000          _DEJ2000            Source       ...  VAGN Vmicro  VCC
#        deg               deg                            ...
#      float64           float64             int64        ... uint8 uint8  uint8
# ----------------- ----------------- ------------------- ... ----- ------ -----
# 342.6645053456925  45.1343449812481 1935790967751641984 ...     0      0     0

# %%
gaia_source = Vizier(catalog=f"I/358/{g_var_lookup['VCR']}", columns=['*']).query_constraints(Source='1935790967751641984')

# %%
gaia_source[0]
# Out:
# <Table length=1>
#        Source             SolID        ...     RA_ICRS         DE_ICRS
#                                        ...       deg             deg
#        int64              int64        ...     float64         float64
# ------------------- ------------------ ... --------------- ---------------
# 1935790967751641984 375316653866487564 ... 342.66450534569  45.13434498125

# %%
gaia_source = Vizier(catalog=f"I/358/{g_var_lookup['VCR']}", columns=['*']).query_constraints(Source='2881005998495586304')

# %%
gaia_source[0]
# Out:
# <Table length=1>
#        Source             SolID        ...     RA_ICRS         DE_ICRS
#                                        ...       deg             deg
#        int64              int64        ...     float64         float64
# ------------------- ------------------ ... --------------- ---------------
# 2881005998495586304 375316653866487564 ...   0.79655033680  38.92034591682

# %%
for el in ['4013710404844589568', '4581399871861478144', '5761980725332338944', '859132616140394880', '2881005998495586304', 
           '3358091992230790656', '790599854521430656', '635168802007228800', '4590789357564268544', '1948787229553042048']:
    info = Vizier(catalog="I/358/varisum", columns=['*', '_RAJ2000', '_DEJ2000']).query_constraints(Source=el)
    print(info[0]['BPmagmean'])
# Out:
# BPmagmean
#    mag
# ---------
# 13.869082
# BPmagmean
#    mag
# ---------
# 13.882474
# BPmagmean
#    mag
# ---------
# 14.904432
# BPmagmean
#    mag
# ---------
# 12.936710
# BPmagmean
#    mag
# ---------
# 14.288805
# BPmagmean
#    mag
# ---------
# 12.960526
# BPmagmean
#    mag
# ---------
# 14.822715
# BPmagmean
#    mag
# ---------
# 13.916607
# BPmagmean
#    mag
# ---------
# 14.087863
# BPmagmean
#    mag
# ---------
# 14.746354

# %%
for el in ['1935790967751641984', '181884718160167168', '2682796448944703360', '65732447241199744', '303350653899042560', 
           '1349332321854811648', '3826586651216916224', '3827474811798428928', '3078113558220776832', '66754241438299520']:
    info = Vizier(catalog="I/358/varisum", columns=['*', '_RAJ2000', '_DEJ2000']).query_constraints(Source=el)
    print(info[0]['BPmagmean'])
# Out:
# BPmagmean
#    mag
# ---------
# 15.026777
# BPmagmean
#    mag
# ---------
# 14.440270
# BPmagmean
#    mag
# ---------
# 12.015363
# BPmagmean
#    mag
# ---------
# 12.838385
# BPmagmean
#    mag
# ---------
# 13.177776
# BPmagmean
#    mag
# ---------
# 15.215676
# BPmagmean
#    mag
# ---------
# 12.544016
# BPmagmean
#    mag
# ---------
# 13.404121
# BPmagmean
#    mag
# ---------
# 14.254376
# BPmagmean
#    mag
# ---------
# 13.383809

# %%
info
# Out:
# TableList with 1 tables:
# 	'0:I/358/varisum' with 26 column(s) and 1 row(s)

# %%
    try:
        
    except:
        # print('Error\n')
        continue
    
    for vtype in g_var_keys:
        if info[vtype] == 1:
            # print(vtype)
            gaia_source = Vizier(catalog=f"I/358/{g_var_lookup[vtype]}", columns=['*']).query_constraints(Source=gid)
            
            if len(gaia_source) > 0:
                gaia_source = gaia_source[0]
# Out:
# {'4013710404844589568': 'RS',
#  '4581399871861478144': 'RS',
#  '5761980725332338944': 'RS',
#  '1399921401603922304': 'LPV',
#  '1935790967751641984': 'RS',
#  '859132616140394880': 'RS',
#  '2881005998495586304': 'RS',
#  '181884718160167168': 'RS',
#  '1909895613489650432': 'RS',
#  '3640488913737117696': 'RS',
#  '339630796700909568': 'RS',
#  '967396269087652480': 'RS',
#  '2833487575548130688': 'RS',
#  '1946031028778798848': 'ECL',
#  '3872321180971475968': 'RS',
#  '379629277372087040': 'RS',
#  '3110488334507902208': 'RS',
#  '3371317777085178624': 'RS',
#  '3353205973013083904': 'RS',
#  '2682796448944703360': 'RS',
#  '328480374405446656': 'RS',
#  '1788142395978292224': 'RS',
#  '360698397264777600': 'RS',
#  '2772707607852294144': 'RS',
#  '2869213358330954368': 'RS',
#  '1924493623214713856': 'LPV',
#  '2840188446083921408': 'RS',
#  '1003618962406707200': 'RS',
#  '1930629619652048768': 'RS',
#  '2695293639840071424': 'RS',
#  '3219200897432361216': 'YSO',
# ...
